# %% [markdown]
# ##### Decorators
# Decorators are a powerful and flexible feature in Python that allows you to modify the behavior of a function or class method. They are commonly used to add functionality to functions or methods without modifying their actual code. This lesson covers the basics of decorators, including how to create and use them.

# %%
### function copy
### closures
### decorators

# %%
### function copy

def welcome():
    return "Welcome to Python Decorators!"

welcome()
# Out:
# 'Welcome to Python Decorators!'

# %%
wel = welcome
print(wel())
del welcome
print(wel())
# Out:
# Welcome to Python Decorators!
# Welcome to Python Decorators!

# %%
### closures

def main_welcome(msg):
    def sub_welcome_method():
        print("Welcome to the Advanced Python Concepts Course!")
        print(msg)
        
        print("Please learn these concepts carefully.")
    return sub_welcome_method()

# %%
main_welcome("Welcome to Python Decorators!")
# Out:
# Welcome to the Advanced Python Concepts Course!
# Welcome to Python Decorators!
# Please learn these concepts carefully.

# %%
def main_welcome(func):
    def sub_welcome_method():
        print("Welcome to the Advanced Python Concepts Course!")
        func("Welcome to Python Decorators!")
        
        print("Please learn these concepts carefully.")
    return sub_welcome_method()

# %%
main_welcome(print)
# Out:
# Welcome to the Advanced Python Concepts Course!
# Welcome to Python Decorators!
# Please learn these concepts carefully.

# %%
def main_welcome(func, lst):
    def sub_welcome_method():
        print("Welcome to the Advanced Python Concepts Course!")
        print(func(lst))
        
        print("Please learn these concepts carefully.")
    return sub_welcome_method()

# %%
main_welcome(len,[1, 2, 3, 4, 5])
# Out:
# Welcome to the Advanced Python Concepts Course!
# 5
# Please learn these concepts carefully.

# %%
len([1, 2, 3, 4, 5])
# Out:
# 5

# %%
### Decorators

def main_welcome(func):
    def sub_welcome_method():
        print("Welcome to the Advanced Python Concepts Course!")
        func()
        
        print("Please learn these concepts carefully.")
    return sub_welcome_method()

# %%
def course_introduction():
    print("This is an advanced Python course focusing on decorators.")
    
course_introduction()
# Out:
# This is an advanced Python course focusing on decorators.

# %%
main_welcome(course_introduction)
# Out:
# Welcome to the Advanced Python Concepts Course!
# This is an advanced Python course focusing on decorators.
# Please learn these concepts carefully.

# %%
@main_welcome
def course_introduction():
    print("This is an advanced Python course focusing on decorators.")
# Out:
# Welcome to the Advanced Python Concepts Course!
# This is an advanced Python course focusing on decorators.
# Please learn these concepts carefully.

# %%
## Decorator

def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper

# %%
@my_decorator
def say_hello():
    print("Hello!")

# %%
say_hello()
# Out:
# Something is happening before the function is called.
# Hello!
# Something is happening after the function is called.

# %%
## Decorators WWith arguments
def repeat(n):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(n):
                func(*args, **kwargs)
        return wrapper
    return decorator

# %%
@repeat(3)
def say_hello():
    print("Hello")

# %%
say_hello()
# Out:
# Hello
# Hello
# Hello

# %% [markdown]
# ##### Conclusion
# Decorators are a powerful tool in Python for extending and modifying the behavior of functions and methods. They provide a clean and readable way to add functionality such as logging, timing, access control, and more without changing the original code. Understanding and using decorators effectively can significantly enhance your Python programming skills.
